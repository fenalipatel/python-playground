# %%
import pandas as pd
import requests

#read csv
dp=pd.read_csv("dog_list.csv")

#get total number of records
len(dp)

#get random number
import random

result=random.randint(0,196)
print(result)

#get result of random number
random_dog=dp.iloc[result]["Breed names"]
print(random_dog)

url= "https://dog.ceo/api/breed/{}/images/random".format(random_dog)
print(url)

from urllib import request
from PIL import Image
from urllib.request import urlopen

url = 'https://images.dog.ceo/breeds/otterhound/n02091635_2112.jpg'
filename = 'image.jpg'
request.urlretrieve(url, filename)
img = Image.open(filename)
img.show()

from IPython.display import display

# Open the image file
img = Image.open("image.jpg")

# Display the image in the notebook
display(img)
# Out:
# 28
# dane
# https://dog.ceo/api/breed/dane/images/random
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x227>

# %%
from datetime import datetime
date = datetime.utcnow()
file_name = f"dog_{random_dog}_{date.strftime('%Y-%m-%d')}.jpg"
print(file_name)
# Out:
# dog_newfoundland_2023-02-14.jpg
